# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup

# %%
asession = AsyncHTMLSession()
r = asession.get("https://livetiming.alkamelsystems.com/imsa")
await r.arender()
print(r.html)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-fbbac961df1b> in <module>
#       1 asession = AsyncHTMLSession()
#       2 r = asession.get("https://livetiming.alkamelsystems.com/imsa")
# ----> 3 await r.arender()
#       4 print(r.html)
#
# AttributeError: '_asyncio.Future' object has no attribute 'arender'
