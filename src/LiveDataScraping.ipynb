# %%
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import sys
import time

# ARGS (optional): takes the url of the livetiming, number of queries, and the time between queries (seconds)
url = 'https://livetiming.alkamelsystems.com/lcsc'# sys.argv[1] if (len(sys.argv) > 1) else 'https://livetiming.alkamelsystems.com/lcsc'
max_hits = 3#int(sys.argv[2]) if (len(sys.argv) > 2) else 3
interval = 5#int(sys.argv[3]) if (len(sys.argv) > 3) else 5

chromedriver_path = '../chromedriver'

options = webdriver.ChromeOptions()
options.headless = True
options.add_experimental_option('excludeSwitches', ['enable-logging'])
driver = webdriver.Chrome(options=options, executable_path=chromedriver_path)

driver.delete_all_cookies()
driver.implicitly_wait(15)

driver.get(url)
driver.refresh()

driver.find_element_by_css_selector('#accept').click()

weather_samples = []
table_samples = []
for _ in range(max_hits):

    weather_sample = []
    for ele in driver.find_elements_by_css_selector('.label.label-weather.col-xs-8+*'):
        weather_sample.append(ele.text)

    print('track temp: {} temp: {} humidity: {} windspeed: {}'.format(*weather_sample))

    try:
        weather_samples.append([int(re.sub(r'[^0-9]', '', e)) for e in weather_sample])
    except ValueError as e:
        weather_samples.append([re.sub(r'[^0-9]', '', e) for e in weather_sample])

    #for something like driver info
    table_sample = []
    for ele in driver.find_elements_by_xpath("//table/tbody/tr"):
        row = [field.text for field in ele.find_elements_by_css_selector("*") if field.text]
        table_sample.append(row)

    table_samples.append(table_sample)

    time.sleep(interval)

print(weather_samples)
print(table_samples)

driver.quit()
# Out:
# track temp: 30Cº temp: 28Cº humidity: 42% windspeed: 21Kph
# track temp: 30Cº temp: 28Cº humidity: 42% windspeed: 24Kph
# track temp: 30Cº temp: 28Cº humidity: 42% windspeed: 24Kph
# [[30, 28, 42, 21], [30, 28, 42, 24], [30, 28, 42, 24]]
# [[['P', '1', '1', '40', 'Grey', 'AL', '2:13.656', '2:13.656', '-', '-', '29.0', '34.2', '32.5', '37.7', '1', '1'], ['2', '2', '32', 'Grey', 'AL', '2:16.495', '2:16.495', '2.839', '2.839', '29.6', '35.2', '33.3', '38.0', '1', '1'], ['P', '3', '3', '24', 'Grey', 'AL', '2:18.974', '2:18.974', '5.318', '5.318', '29.9', '35.4', '33.4', '38.9', '1', '1'], ['P', '4', '4', '27', 'Grey', 'WEH', '2:19.758', '2:19.758', '6.102', '6.102', '30.4', '35.7', '33.0', '39.8', '1', '1'], ['P', '5', '5', '51', 'Grey', 'AL', '2:24.141', '2:24.141', '10.485', '10.485', '31.5', '36.7', '34.7', '40.7', '1', '1'], ['P', '6', '6', '89', 'Grey', 'AL', '2:24.688', '2:24.688', '11.032', '11.032', '31.3', '36.6', '35.1', '40.6', '1', '1'], ['P', '7', '7', '18', 'Grey', 'AL', '2:30.289', '2:30.289', '16.633', '16.633', '32.8', '38.1', '37.3', '41.9', '1', '1'], ['P', '8', '8', '22', 'Grey', 'TER', '0', '0'], ['P', '9', '9', '30', 'Grey', 'AL', '0', '0'], ['P', '10', '10', '31', 'Grey', 'ALA', '0', '0'], ['P', '11', '11', '39', 'Grey', 'MAL', '0', '0'], ['P', '12', '12', '41', 'Grey', 'AL', '0', '0'], ['P', '13', '13', '44', 'Grey', 'AL', '0', '0'], ['P', '14', '14', '96', 'Grey', 'AL', '0', '0']], [['P', '1', '1', '40', 'Grey', 'AL', '2:13.656', '2:13.656', '-', '-', '29.0', '34.2', '32.5', '37.7', '1', '1'], ['2', '2', '32', 'Grey', 'AL', '2:16.495', '2:16.495', '2.839', '2.839', '29.6', '35.2', '33.3', '38.0', '1', '1'], ['P', '3', '3', '24', 'Grey', 'AL', '2:18.974', '2:18.974', '5.318', '5.318', '29.9', '35.4', '33.4', '38.9', '1', '1'], ['P', '4', '4', '27', 'Grey', 'WEH', '2:19.758', '2:19.758', '6.102', '6.102', '30.4', '35.7', '33.0', '39.8', '1', '1'], ['P', '5', '5', '51', 'Grey', 'AL', '2:24.141', '2:24.141', '10.485', '10.485', '31.5', '36.7', '34.7', '40.7', '1', '1'], ['P', '6', '6', '89', 'Grey', 'AL', '2:24.688', '2:24.688', '11.032', '11.032', '31.3', '36.6', '35.1', '40.6', '1', '1'], ['P', '7', '7', '18', 'Grey', 'AL', '2:30.289', '2:30.289', '16.633', '16.633', '32.8', '38.1', '37.3', '41.9', '1', '1'], ['P', '8', '8', '22', 'Grey', 'TER', '0', '0'], ['P', '9', '9', '30', 'Grey', 'AL', '0', '0'], ['P', '10', '10', '31', 'Grey', 'ALA', '0', '0'], ['P', '11', '11', '39', 'Grey', 'MAL', '0', '0'], ['P', '12', '12', '41', 'Grey', 'AL', '0', '0'], ['P', '13', '13', '44', 'Grey', 'AL', '0', '0'], ['P', '14', '14', '96', 'Grey', 'AL', '0', '0']], [['P', '1', '1', '40', 'Grey', 'AL', '2:13.656', '2:13.656', '-', '-', '29.0', '34.2', '32.5', '37.7', '1', '1'], ['2', '2', '32', 'Grey', 'AL', '2:16.495', '2:16.495', '2.839', '2.839', '29.6', '35.2', '33.3', '38.0', '1', '1'], ['P', '3', '3', '24', 'Grey', 'AL', '2:18.974', '2:18.974', '5.318', '5.318', '29.9', '35.4', '33.4', '38.9', '1', '1'], ['P', '4', '4', '27', 'Grey', 'WEH', '2:19.758', '2:19.758', '6.102', '6.102', '30.4', '35.7', '33.0', '39.8', '1', '1'], ['P', '5', '5', '51', 'Grey', 'AL', '2:24.141', '2:24.141', '10.485', '10.485', '31.5', '36.7', '34.7', '40.7', '1', '1'], ['P', '6', '6', '89', 'Grey', 'AL', '2:24.688', '2:24.688', '11.032', '11.032', '31.3', '36.6', '35.1', '40.6', '1', '1'], ['P', '7', '7', '18', 'Grey', 'AL', '2:30.289', '2:30.289', '16.633', '16.633', '32.8', '38.1', '37.3', '41.9', '1', '1'], ['P', '8', '8', '22', 'Grey', 'TER', '0', '0'], ['P', '9', '9', '30', 'Grey', 'AL', '0', '0'], ['P', '10', '10', '31', 'Grey', 'ALA', '0', '0'], ['P', '11', '11', '39', 'Grey', 'MAL', '0', '0'], ['P', '12', '12', '41', 'Grey', 'AL', '0', '0'], ['P', '13', '13', '44', 'Grey', 'AL', '0', '0'], ['P', '14', '14', '96', 'Grey', 'AL', '0', '0']]]

# %%
# Out:
# <!DOCTYPE html><html><head>
#   <link rel="stylesheet" type="text/css" class="__meteor-css__" href="/b552c30bd5f5e2574a30eb4c477cabca7f29c860.css?meteor_css_resource=true">
# <title>LT2</title>
#   <link rel="icon" sizes="16x16 32x32 64x64 128x128 256x256 512x512" href="/favicon.ico?v=1">
#   <meta name="viewport" content="width=device-width">
#   <!-- Global site tag (gtag.js) - Google Analytics -->
# <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-157725126-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-157725126-1');
# </script>
#
# </head>
# <body>
#   <script type="text/javascript">__meteor_runtime_config__ = JSON.parse(decodeURIComponent("%7B%22meteorRelease%22%3A%22METEOR%401.9.2%22%2C%22gitCommitHash%22%3A%22e15d6107eea988db4b82a93629cf84c613892db6%22%2C%22meteorEnv%22%3A%7B%22NODE_ENV%22%3A%22production%22%2C%22TEST_METADATA%22%3A%22%7B%7D%22%7D%2C%22PUBLIC_SETTINGS%22%3A%7B%7D%2C%22ROOT_URL%22%3A%22http%3A%2F%2Ffeeds-config.alkamelsystems.com%22%2C%22ROOT_URL_PATH_PREFIX%22%3A%22%22%2C%22autoupdate%22%3A%7B%22versions%22%3A%7B%22web.browser%22%3A%7B%22version%22%3A%22917e799de2315b6f1d8ca52bc3f32f3f4a56a01d%22%2C%22versionRefreshable%22%3A%2284b7694db750082d7618464e747c06177f8f5e2e%22%2C%22versionNonRefreshable%22%3A%22df7447fbdb57785b0187376c3655441051dd3ae1%22%7D%2C%22web.browser.legacy%22%3A%7B%22version%22%3A%2296f0cd84f6306fe5c47631a1ffef282039382d51%22%2C%22versionRefreshable%22%3A%2284b7694db750082d7618464e747c06177f8f5e2e%22%2C%22versionNonRefreshable%22%3A%2228458d628fc013d21aec7bd66906ca6e51a3b603%22%7D%7D%2C%22autoupdateVersion%22%3Anull%2C%22autoupdateVersionRefreshable%22%3Anull%2C%22autoupdateVersionCordova%22%3Anull%2C%22appId%22%3A%22v6g3cooqfixtiz3clx%22%7D%2C%22appId%22%3A%22v6g3cooqfixtiz3clx%22%2C%22accountsConfigCalled%22%3Atrue%2C%22isModern%22%3Atrue%7D"))</script>
#
#   <script type="text/javascript" src="/416157994a92fb3258c0303b8bffebe4daed5c84.js?meteor_js_resource=true"></script>
#
#
#
# </body></html>
