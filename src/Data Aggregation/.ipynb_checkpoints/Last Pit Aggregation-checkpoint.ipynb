# %%
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

# %%
sp17 = pd.read_csv('../../data/2017/17_stopped_car_pit.csv')
sp18 = pd.read_csv('../../data/2018/18_stopped_car_pit.csv')
sp19 = pd.read_csv('../../data/2019/19_stopped_car_pit.csv')
sp20 = pd.read_csv('../../data/2020/20_stopped_car_pit.csv')

# %%
stopped_pit_agg = pd.concat([sp17, sp18, sp19, sp20])
hist = stopped_pit_agg.hist(column='Last Pit', bins=8)
hist
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001687F25D148>]],
#       dtype=object)

# %%
mean,std= norm.fit(stopped_pit_agg['Last Pit'])
plt.hist(stopped_pit_agg['Last Pit'], bins=10, density=True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, mean, std)
plt.plot(x, y)
plt.show()

# %%
data = stopped_pit_agg['Last Pit']
data = data.where(data < 40).dropna()
data_neg = data.multiply(-1)
mirrored_data = pd.concat([data, data_neg])

# %%
mean1,std1= norm.fit(mirrored_data)
plt.hist(mirrored_data, bins=8, density=True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, mean1, std1) *2
plt.plot(x, y)
plt.show()

# %%
data = stopped_pit_agg['Last Pit']
data = data.where(data >= 40).dropna()
data_neg = data.multiply(-1)
diff = min(data) * 2
data_neg = data_neg.add(diff)
mirrored_data = pd.concat([data, data_neg])
plt.hist(mirrored_data, bins=6)
# Out:
# (array([1., 2., 2., 4., 2., 1.]),
#  array([18.84138333, 25.98207222, 33.12276111, 40.26345   , 47.40413889,
#         54.54482778, 61.68551667]),
#  <a list of 6 Patch objects>)

# %%
mean2,std2= norm.fit(mirrored_data)
plt.hist(mirrored_data, bins=6, density=True)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
y = norm.pdf(x, mean2, std2) 
plt.plot(x, y)
plt.show()

# %%
data = stopped_pit_agg['Last Pit']
data
# Out:
# 0    37.846783
# 1     5.299950
# 2    53.083583
# 3    10.851867
# 4     5.190600
# 5    45.254833
# 6    41.612117
# 0    40.263450
# 1     1.082583
# 2    19.044750
# 0    26.504300
# 1     1.524733
# 2     4.884600
# 3    25.191650
# 4    11.407267
# 5    10.717083
# 6     4.688317
# 7    53.097717
# 8     7.341067
# 0     8.675467
# 1    18.676083
# 2    61.685517
# 3     3.046883
# 4    17.318167
# Name: Last Pit, dtype: float64

# %%
y = []
for d in data:
    y_hat = norm.pdf(d, mean1, mean2) if d < 40 else
# Out:
#   File "<ipython-input-53-e94067d63fc5>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing
