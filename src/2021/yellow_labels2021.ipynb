# %%
import pandas as pd
from datetime import datetime, timedelta, date
from collections import defaultdict
import json

# %%
df = pd.read_csv('../../data/2021/2021_mod.csv')

# %%
flag_times = []
green_flag = True
for index, row in df.iterrows():
    if row.Flag == 'Green':
        green_flag = True
    elif green_flag and row.Flag == 'Yellow':
        flag_times.append(row['Session Time'])
        green_flag = False
flag_times
# Out:
# ['1900-01-01 00:08:51.445000',
#  '1900-01-01 01:15:27.474000',
#  '1900-01-01 01:56:56.721000',
#  '1900-01-01 02:22:58.734000',
#  '1900-01-01 06:29:36.040000',
#  '1900-01-01 10:11:02.364000',
#  '1900-01-01 13:02:48.292000',
#  '1900-01-01 14:44:23.569000',
#  '1900-01-01 16:08:20.408000',
#  '1900-01-01 18:30:39.638000',
#  '1900-01-01 21:34:26.196000',
#  '1900-01-01 22:02:16.612000']

# %%
yellow_flag_second_times = []
for f in flag_times:
    first_flag = datetime.strptime(f, '%Y-%m-%d %H:%M:%S.%f')
    starting_date = datetime(1900, 1, 1)
    flag_seconds = (first_flag - starting_date).total_seconds()
    flag_seconds = flag_seconds//20 * 20
    yellow_flag_second_times.append(flag_seconds)
yellow_flag_second_times
# Out:
# [520.0,
#  4520.0,
#  7000.0,
#  8560.0,
#  23360.0,
#  36660.0,
#  46960.0,
#  53060.0,
#  58100.0,
#  66620.0,
#  77660.0,
#  79320.0]

# %%
with open('../../data/2021/21_num_drivers.json') as json_file:
    d = json.load(json_file)
    
times = list(d.keys())
times = [int(t) for t in times]
MAXTIME = max(times)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6fa34bfbe9c9> in <module>
# ----> 1 with open('../../data/2021/21_num_drivers.json') as json_file:
#       2     d = json.load(json_file)
#       3
#       4 times = list(d.keys())
#       5 times = [int(t) for t in times]
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/2021/21_num_drivers.json'

# %%
is_yellow = {}
for t in range(20, MAXTIME+1, 20):
    if t in yellow_flag_second_times or (t+20) in yellow_flag_second_times or (t+40) in yellow_flag_second_times or (t+60) in yellow_flag_second_times:
        is_yellow[t] = 1
    else:
        is_yellow[t] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-85fa88765890> in <module>
#       1 is_yellow = {}
# ----> 2 for t in range(20, MAXTIME+1, 20):
#       3     if t in yellow_flag_second_times or (t+20) in yellow_flag_second_times or (t+40) in yellow_flag_second_times or (t+60) in yellow_flag_second_times:
#       4         is_yellow[t] = 1
#       5     else:
#
# NameError: name 'MAXTIME' is not defined

# %%
with open('../../data/2020/20_yellow_labels.csv', 'w') as f:
    f.write('Time,Yellow\n')
    for key in is_yellow.keys():
        f.write("%s,%s\n"%(key, is_yellow[key]))
