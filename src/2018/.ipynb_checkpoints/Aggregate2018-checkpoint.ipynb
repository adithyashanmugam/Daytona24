# %%
import pandas as pd

# %%
concentration = pd.read_csv('../../data/2018/18_concentrations.csv')
labels = pd.read_csv('../../data/2018/18_yellow_labels.csv')
pit = pd.read_csv('../../data/2018/18_time_since_pit.csv')
weather = pd.read_csv('../../data/weather_data/2018_weather.csv', sep=';')

# %%
max_concentration = pd.DataFrame(columns=['Time', 'Max Concentration'])
temp_max = 0
for index, row in concentration.iterrows():
    sector = row[1]
    if sector == 1:
        temp_max = 0
    if row[2] > temp_max:
        temp_max = row[2]
    if sector == 13:
        max_concentration.loc[index] = [row[0], temp_max]

# %%
start_time = weather['TIME_UTC_SECONDS'].iloc[0]

with open('../../data/2018/weather_mod.csv', 'w') as f:
    f.write('Time,Track Temp,Wind Speed,Rain\n')
    for index, row in weather.iterrows():
            if row['TRACK_TEMP'] != 32:
                temp = row['TRACK_TEMP']
            else:
                row['TRACK_TEMP'] = temp
        
            f.write("%s,%s,%s,%s\n"%((row[0]-start_time)//20 * 20, row[3], row[6], row[8]))
            f.write("%s,%s,%s,%s\n"%((row[0]-start_time+20)//20 * 20, row[3], row[6], row[8]))
            f.write("%s,%s,%s,%s\n"%((row[0]-start_time+40)//20 * 20, row[3], row[6], row[8]))
weather_mod = pd.read_csv('../../data/2018/18_weather_mod.csv')
weather_mod[weather_mod['Time'] == 16940]
# Out:
#       Time  Track Temp  Wind Speed  Rain
# 846  16940    66.00002         1.9   NaN

# %%
agg = max_concentration.merge(pit, how='inner', on='Time')
agg = agg.merge(weather_mod, how='inner', on='Time')
agg = agg.merge(labels, how='inner', on='Time')
agg
# Out:
#          Time  Max Concentration   Last Pit  Track Temp  Wind Speed  Rain  \
# 0        20.0          27.407742   0.333333    78.00008         2.6   NaN
# 1        40.0          22.615864   0.666667    78.00008         2.6   NaN
# 2        60.0          12.329932   1.000000    78.00008         2.6   NaN
# 3        80.0          20.322355   1.333333    78.00008         2.6   NaN
# 4       100.0          11.667811   1.666667    78.00008         2.6   NaN
# ...       ...                ...        ...         ...         ...   ...
# 4307  86360.0           4.567957  51.820333    78.00008         1.9   NaN
# 4308  86380.0           6.280941  52.153667    78.00008         1.9   NaN
# 4309  86400.0           5.709946  52.487000    78.00008         3.2   NaN
# 4310  86420.0           6.851935  52.820333    78.00008         3.2   NaN
# 4311  86440.0           6.219363  53.153667    78.00008         3.2   NaN
#
#       Yellow
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4307       0
# 4308       0
# 4309       0
# 4310       0
# 4311       0
#
# [4312 rows x 7 columns]

# %%
agg.to_csv('../../data/2018/18_agg_data.csv', index=False)
