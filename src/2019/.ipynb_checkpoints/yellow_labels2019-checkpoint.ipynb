# %%
import pandas as pd
from datetime import datetime, timedelta, date
from collections import defaultdict
import json

# %%
df = pd.read_csv('../../data/2019/2019_mod.csv')

# %%
flag_times = []
green_flag = True
for index, row in df.iterrows():
    if row.Flag == 'Green':
        green_flag = True
    elif green_flag and row.Flag == 'Yellow':
        flag_times.append(row['Session Time'])
        green_flag = False
flag_times
# Out:
# ['1900-01-01 01:37:49.471000',
#  '1900-01-01 02:43:17.079000',
#  '1900-01-01 03:50:17.379000',
#  '1900-01-01 05:41:12.287000',
#  '1900-01-01 06:43:38.055000',
#  '1900-01-01 08:02:18.555000',
#  '1900-01-01 10:05:55.517000',
#  '1900-01-01 11:56:04.203000',
#  '1900-01-01 13:28:38.031000',
#  '1900-01-01 14:36:40.636000',
#  '1900-01-01 15:28:17.286000',
#  '1900-01-01 18:33:44.341000',
#  '1900-01-01 20:24:42.529000',
#  '1900-01-01 20:51:27.734000',
#  '1900-01-01 21:08:24.809000',
#  '1900-01-01 21:27:53.302000',
#  '1900-01-01 21:57:43.908000']

# %%
# 99, 24, 50, 52, 77, 47, 50, 3, 55, [debris], 4 (hydroplane), [red to yellow], [a million collisions, 540], [540 spin], [debris], collision[63, 540], 18

# %%
yellow_flag_second_times = []
for f in flag_times:
    first_flag = datetime.strptime(f, '%Y-%m-%d %H:%M:%S.%f')
    starting_date = datetime(1900, 1, 1)
    flag_seconds = (first_flag - starting_date).total_seconds()
    flag_seconds = flag_seconds//20 * 20
    yellow_flag_second_times.append(flag_seconds)
yellow_flag_second_times
# Out:
# [5860.0,
#  9780.0,
#  13800.0,
#  20460.0,
#  24200.0,
#  28920.0,
#  36340.0,
#  42960.0,
#  48500.0,
#  52600.0,
#  55680.0,
#  66820.0,
#  73480.0,
#  75080.0,
#  76100.0,
#  77260.0,
#  79060.0]

# %%
with open('../../data/2019/19_count_wspeed.json') as json_file:
    d = json.load(json_file)
    
times = list(d.keys())
times = [int(t) for t in times]
MAXTIME = max(times)

# %%
is_yellow = {}
for t in range(20, MAXTIME+1, 20):
    if t in yellow_flag_second_times or (t+20) in yellow_flag_second_times or (t+40) in yellow_flag_second_times or (t+60) in yellow_flag_second_times:
        is_yellow[t] = 1
    else:
        is_yellow[t] = 0

# %%
with open('../../data/2019/19_yellow_labels.csv', 'w') as f:
    f.write('Time,Yellow\n')
    for key in is_yellow.keys():
        f.write("%s,%s\n"%(key, is_yellow[key]))
